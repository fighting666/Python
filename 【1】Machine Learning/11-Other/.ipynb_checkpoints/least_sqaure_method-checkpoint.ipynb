# %% [markdown]
# #### 最小二乘法
# 高斯于1823年在误差e1 ,… , en独立同分布的假定下,证明了最小二乘方法的一个最优性质: 在所有无偏的线性估计类中,最小二乘方法是其中方差最小的！
#
# 使用最小二乘法拟和曲线
# 对于数据$(x_i, y_i)(i=1, 2, 3...,m)$
#
# 拟合出函数$h(x)$
#
# 有误差，即残差：$r_i=h(x_i)-y_i$
#
# 此时L2范数(残差平方和)最小时，h(x) 和 y 相似度最高，更拟合
#
# 一般的H(x)为n次的多项式，$H(x)=w_0+w_1x+w_2x^2+...w_nx^n$
#
# $w(w_0,w_1,w_2,...,w_n)$为参数
#
# 最小二乘法就是要找到一组 $w(w_0,w_1,w_2,...,w_n)$ 使得$\sum_{i=1}^n(h(x_i)-y_i)^2$ (残差平方和) 最小
#
# 即，求 $min\sum_{i=1}^n(h(x_i)-y_i)^2$

# %% [markdown]
# 举例：我们用目标函数$y=sin2{\pi}x$, 加上一个正太分布的噪音干扰，用多项式去拟合【例1.1 11页】

# %%
import numpy as np
import scipy as sp
from scipy.optimize import leastsq # 最小二乘法函数leastsq
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 目标函数（真实函数）
def real_func(x):
    return np.sin(2 * np.pi * x)


# 生成多项式函数
def fit_func(p, x):
    f = np.poly1d(p)  # 多项式函数 np.poly1d()
    #     print('多项式函数为:%s' % f)
    return f(x)


# np.poly1d([1,2,3],True,variable=‘z’)
# 参数1：为一个数组，若没有参数2，则生成一个多项式
# 若参数2为True，则表示把数组中的值作为根，然后反推多项式
# variable=‘z’表示改变未知数的字母
# 微分 p.deriv()
# 积分 p.integ()
# 多项式函数的根 np.roots(p)


# 残差
def residuals_func(p, x, y):
    ret = fit_func(p, x) - y
    return ret

# %%
# 生成10个数据点
x = np.linspace(0, 1, 10)
x_points = np.linspace(0, 1, 1000)
# 加上正态分布噪音的目标函数的值 y
y_ = real_func(x)  # 生成 y 值
y = [np.random.normal(0, 0.1) + y1 for y1 in y_]


def fitting(M=0):
    """
    M 为多项式的次数
    """
    # 随机初始化多项式参数
    p_init = np.random.rand(M + 1)  # 系数比次数多1
    # 最小二乘法
    p_lsq = leastsq(
        residuals_func, p_init, args=(x, y))  # scipy中最小二乘法函数leastsq
    print('Fitting Parameters:', p_lsq[0])

    # 可视化
    plt.plot(x_points, real_func(x_points), label='real')
    plt.plot(x_points, fit_func(p_lsq[0], x_points), label='fitted curve')
    plt.plot(x, y, 'bo', label='noise')
    plt.legend()
    return p_lsq

# %%
# M=0
p_lsq_0 = fitting(M=0)
# Out:
# Fitting Parameters: [-0.07068221]

# %%
# M=1
p_lsq_1 = fitting(M=1)
# Out:
# Fitting Parameters: [-1.40598993  0.63231276]

# %%
# M=3
p_lsq_3 = fitting(M=3)
# Out:
# Fitting Parameters: [ 21.38156545 -32.20994648  10.90062279  -0.12718802]

# %%
# M=9
p_lsq_9 = fitting(M=9)
# Out:
# Fitting Parameters: [-1.82709577e+04  8.25384816e+04 -1.56891763e+05  1.63046033e+05
#  -1.00711826e+05  3.76170211e+04 -8.22578601e+03  9.34242648e+02
#  -3.54974036e+01 -5.76292527e-02]

# %% [markdown]
# #### 正则化
#
# 结果显示过拟合， 引入正则化项(regularizer)，降低过拟合
#
# 正则化项：零范数、一范数、二范数、迹范数、Frobenius范数和核范数
#
# $Q(x)=\sum_{i=1}^n(h(x_i)-y_i)^2+\lambda||w||^2$
#
# 对于第一项Loss函数，
#
# (1) 如果是Square loss，那就是最小二乘法
#
# (2) 如果是Hinge Loss，那就是著名的SVM
#
# (3) 如果是exp-Loss，那就是牛逼的 Boosting
#
# (4) 如果是log-Loss，那就是Logistic Regression
#
# (5) 回归问题中，损失函数是平方损失，正则化可以是参数向量的L2范数,也可以是L1范数。
#
# L1: regularization*abs(p)
#
# L2: 0.5 * regularization * np.square(p)

# %%
regularization = 0.0001

def residuals_func_regularization(p, x, y):
    ret = fit_func(p, x) - y
    ret = np.append(ret, np.sqrt(0.5*regularization*np.square(p))) # L2范数作为正则化项
    return ret

# %%
# 最小二乘法,加正则化项
p_init = np.random.rand(9+1)
p_lsq_regularization = leastsq(residuals_func_regularization, p_init, args=(x, y))
# residuals_func_regularization(p_init,x,y)
# p_lsq_regularization

# %%
plt.plot(x_points, real_func(x_points), label='real')
plt.plot(x_points, fit_func(p_lsq_9[0], x_points), label='fitted curve')
plt.plot(x_points, fit_func(p_lsq_regularization[0], x_points), label='regularization')
plt.plot(x, y, 'bo', label='noise')
plt.legend()
